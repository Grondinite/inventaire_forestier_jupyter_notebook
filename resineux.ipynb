# %% [markdown]
# # Sample Resineux

# %%
from utils import import_tree_dataset, get_biomass_summary, get_biomass_summary_by_species

df_resineux = import_tree_dataset("./data/arbres_resineux.csv")
df_resineux
# Out:
#     num         species   dph  height
# 0     1  épinette_noire  29.6    17.3
# 1     2  épinette_noire  17.8    17.4
# 2     3  épinette_noire  17.7    15.9
# 3     4  épinette_noire  23.0    20.1
# 4     5  épinette_noire  24.1    17.8
# 5     6  épinette_noire  27.8    16.7
# 7    8A  épinette_noire  22.8    14.8
# 8    8B   bouleau_blanc  11.7    11.3
# 9     9  épinette_noire  11.3    15.0
# 10   10    érable_rouge  30.1    18.2
# 11   11    érable_rouge  14.0    16.6
# 12   12    érable_rouge  24.7    11.5
# 13   13  épinette_noire  20.0    14.0
# 14   14  épinette_noire  26.8    21.7
# 15   15   bouleau_blanc  16.4    13.8
# 16   16  épinette_noire  29.0    20.4
# 17   17  épinette_noire  10.0     9.2
# 19   19   bouleau_blanc  13.0    14.0
# 20   20  épinette_noire  10.9    14.0
# 21  21A   bouleau_blanc  11.2    14.0
# 22  21B   bouleau_blanc   9.8     3.4
# 23   22  épinette_noire  20.9    16.0
# 24   23  épinette_noire  26.5    20.1
# 25   24    érable_rouge  19.0    13.2
# ...

# %% [markdown]
# ## Distrib normale

# %%
from utils import generate_normal_tree_distribution

generate_normal_tree_distribution(df_resineux, label="Resineux")

# %% [markdown]
# ## Application du calcul de biomasse

# %%
from utils import generate_biomass_estimation

generate_biomass_estimation(df_resineux)
# Out:
#     num         species   dph  height     biomass
# 0     1  épinette_noire  29.6    17.3  296.883005
# 1     2  épinette_noire  17.8    17.4  109.750472
# 2     3  épinette_noire  17.7    15.9  102.672007
# 3     4  épinette_noire  23.0    20.1  196.660118
# 4     5  épinette_noire  24.1    17.8  199.887992
# 5     6  épinette_noire  27.8    16.7  257.444994
# 7    8A  épinette_noire  22.8    14.8  163.565199
# 8    8B   bouleau_blanc  11.7    11.3   43.508829
# 9     9  épinette_noire  11.3    15.0   42.026419
# 10   10    érable_rouge  30.1    18.2  398.718623
# 11   11    érable_rouge  14.0    16.6   75.423672
# 12   12    érable_rouge  24.7    11.5  207.752707
# 13   13  épinette_noire  20.0    14.0  122.518146
# 14   14  épinette_noire  26.8    21.7  276.934741
# 15   15   bouleau_blanc  16.4    13.8   99.184501
# 16   16  épinette_noire  29.0    20.4  310.260146
# 17   17  épinette_noire  10.0     9.2   25.466612
# 19   19   bouleau_blanc  13.0    14.0   59.464078
# ...

# %%
get_biomass_summary(df_resineux)
# Out:
#             biomass
# mean     175.431344
# median   179.499689
# sum     6490.959727
# count     37.000000

# %%
get_biomass_summary_by_species(df_resineux)
# Out:
#                       mean      median          sum  count
# species
# bouleau_blanc    48.714256   43.508829   340.999794      7
# épinette_noire  205.413338  204.572907  5340.746780     26
# érable_rouge    202.303288  167.535429   809.213152      4

# %%
# %store df_resineux
# Out:
# Stored 'df_resineux' (DataFrame)
